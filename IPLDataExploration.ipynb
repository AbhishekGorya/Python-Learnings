# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

df = pd.read_csv('IPL.csv')

# %%
df
# Out:
#     match_id           date  ...      best_bowling best_bowling_figure
# 0          1  March 26,2022  ...      Dwayne Bravo               3--20
# 1          2  March 27,2022  ...     Kuldeep Yadav               3--18
# 2          3  March 27,2022  ...    Mohammed Siraj               2--59
# 3          4  March 28,2022  ...    Mohammed Shami               3--25
# 4          5  March 29,2022  ...  Yuzvendra Chahal               3--22
# ..       ...            ...  ...               ...                 ...
# 69        70    May 22,2022  ...     Harpreet Brar               3--26
# 70        71    May 24,2022  ...     Hardik Pandya               1--14
# 71        72    May 25,2022  ...    Josh Hazlewood               3--43
# 72        73    May 27,2022  ...   Prasidh Krishna               3--22
# 73        74    May 29,2022  ...     Hardik Pandya               3--17
#
# [74 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
df.size
# Out:
# 1480

# %%
print(f'yor rows are {df.shape[0]}')
# Out:
# yor rows are 74

# %%
print(f'yor cols are {df.shape[1]}')
# Out:
# yor cols are 20

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
winners = df['match_winner'].value_counts()

# %%
# sns.barplot(data=winners)
sns.barplot(y=winners.index , x=winners.values  , palette='viridis')
plt.title("winning score ")
plt.xlabel('wins')
plt.ylabel('teams')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11644\3035732914.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=winners.index , x=winners.values  , palette='viridis')
# Text(0, 0.5, 'teams')

# %%
df.head()
# Out:
#    match_id           date  ...      best_bowling best_bowling_figure
# 0         1  March 26,2022  ...      Dwayne Bravo               3--20
# 1         2  March 27,2022  ...     Kuldeep Yadav               3--18
# 2         3  March 27,2022  ...    Mohammed Siraj               2--59
# 3         4  March 28,2022  ...    Mohammed Shami               3--25
# 4         5  March 29,2022  ...  Yuzvendra Chahal               3--22
#
# [5 rows x 20 columns]

# %%
sns.countplot(x=df['toss_decision'] , palette='rainbow')
plt.title("Toss Descision Trends ")
plt.xlabel('Trens')
plt.ylabel('toss_choices')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11644\1935188355.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['toss_decision'] , palette='rainbow')
# Text(0, 0.5, 'toss_choices')

# %%
#tosswinner vs matchwinners
comp = df[df['toss_winner'] == df['match_winner']]['match_id'].count()

# %%
comp
# Out:
# 36

# %%
comp.shape
# Out:
# ()

# %%
print(f'the percentage of the matches where the toss winning team is the match winner too is {( comp *100 / df.shape[0]).round()}')
# Out:
# the percentage of the matches where the toss winning team is the match winner too is 49.0

# %%
#how do teams won (runs vs wickets)

# %%
df.head()
# Out:
#    match_id           date  ...      best_bowling best_bowling_figure
# 0         1  March 26,2022  ...      Dwayne Bravo               3--20
# 1         2  March 27,2022  ...     Kuldeep Yadav               3--18
# 2         3  March 27,2022  ...    Mohammed Siraj               2--59
# 3         4  March 28,2022  ...    Mohammed Shami               3--25
# 4         5  March 29,2022  ...  Yuzvendra Chahal               3--22
#
# [5 rows x 20 columns]

# %%
sns.countplot(df['won_by'])
# Out:
# <Axes: xlabel='count', ylabel='won_by'>

# %%
#1 most "player of the match"

# %%
MOM = df['player_of_the_match'].value_counts()

# %%
MOM.head(1)
# Out:
# player_of_the_match
# Kuldeep Yadav    4
# Name: count, dtype: int64

# %%
sns.barplot(y=MOM.head(10).index , x=MOM.head(10).values , palette='mako')

plt.title('Top 10 players with man of the match awards')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11644\187228153.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=MOM.head(10).index , x=MOM.head(10).values , palette='mako')
# Text(0.5, 1.0, 'Top 10 players with man of the match awards')

# %%
#top 10 scorers

# %%
hg = df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(2)

# %%
hg
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# Name: highscore, dtype: int64

# %%
hg.plot(kind='barh')
# Out:
# <Axes: ylabel='top_scorer'>

# %%
# top 10 bowling figures

# %%
df.head()
# Out:
#    match_id           date  ...      best_bowling best_bowling_figure
# 0         1  March 26,2022  ...      Dwayne Bravo               3--20
# 1         2  March 27,2022  ...     Kuldeep Yadav               3--18
# 2         3  March 27,2022  ...    Mohammed Siraj               2--59
# 3         4  March 28,2022  ...    Mohammed Shami               3--25
# 4         5  March 29,2022  ...  Yuzvendra Chahal               3--22
#
# [5 rows x 20 columns]

# %%
df['highest_wickets'] = df['best_bowling_figure'].apply(lambda x: x.split('--')[0])

# %%
df
# Out:
#     match_id           date  ... best_bowling_figure highest_wickets
# 0          1  March 26,2022  ...               3--20               3
# 1          2  March 27,2022  ...               3--18               3
# 2          3  March 27,2022  ...               2--59               2
# 3          4  March 28,2022  ...               3--25               3
# 4          5  March 29,2022  ...               3--22               3
# ..       ...            ...  ...                 ...             ...
# 69        70    May 22,2022  ...               3--26               3
# 70        71    May 24,2022  ...               1--14               1
# 71        72    May 25,2022  ...               3--43               3
# 72        73    May 27,2022  ...               3--22               3
# 73        74    May 29,2022  ...               3--17               3
#
# [74 rows x 21 columns]

# %%
df['highest_wickets'] = df['highest_wickets'].astype(int)

# %%
top_bowlers = df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)

# %%
sns.barplot(x=top_bowlers.values , y=top_bowlers.index)
# Out:
# <Axes: ylabel='best_bowling'>

# %%
#most match played by venue

# %%
vcount = df['venue'].value_counts()

# %%
vcount
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(x =vcount.values , y=vcount.index)
# Out:
# <Axes: ylabel='venue'>

# %%
#who won highest margin by runs

# %%
df
# Out:
#     match_id           date  ... best_bowling_figure highest_wickets
# 0          1  March 26,2022  ...               3--20               3
# 1          2  March 27,2022  ...               3--18               3
# 2          3  March 27,2022  ...               2--59               2
# 3          4  March 28,2022  ...               3--25               3
# 4          5  March 29,2022  ...               3--22               3
# ..       ...            ...  ...                 ...             ...
# 69        70    May 22,2022  ...               3--26               3
# 70        71    May 24,2022  ...               1--14               1
# 71        72    May 25,2022  ...               3--43               3
# 72        73    May 27,2022  ...               3--22               3
# 73        74    May 29,2022  ...               3--17               3
#
# [74 rows x 21 columns]

# %%
mag = df[df['won_by']=='Runs'].sort_values(by='margin' , ascending=False).head(1)[['match_winner' , 'margin']]

# %%
mag
# Out:
#    match_winner  margin
# 54      Chennai      91

# %%
# player with highest individual score

# %%
df.head(1)
# Out:
#    match_id           date                     venue  ...  best_bowling best_bowling_figure highest_wickets
# 0         1  March 26,2022  Wankhede Stadium, Mumbai  ...  Dwayne Bravo               3--20               3
#
# [1 rows x 21 columns]

# %%
player = df.groupby(['top_scorer'])['highscore'].max().sort_values(ascending=False).head(1)

# %%
player
# Out:
# top_scorer
# Quinton de Kock    140
# Name: highscore, dtype: int64

# %%
df[df['highscore']==df['highscore'].max()][['player_of_the_match' , 'highscore']]
# Out:
#    player_of_the_match  highscore
# 65     Quinton de Kock        140

# %%
#best bowling figures

# %%
df.head(2)
# Out:
#    match_id           date                      venue  ...   best_bowling best_bowling_figure highest_wickets
# 0         1  March 26,2022   Wankhede Stadium, Mumbai  ...   Dwayne Bravo               3--20               3
# 1         2  March 27,2022  Brabourne Stadium, Mumbai  ...  Kuldeep Yadav               3--18               3
#
# [2 rows x 21 columns]

# %%
df[df['highest_wickets'] == df['highest_wickets'].max()][['best_bowling' , 'best_bowling_figure']].head(1)
# Out:
#         best_bowling best_bowling_figure
# 29  Yuzvendra Chahal               5--40

# %%
player = df.groupby(['best_bowling'])['highest_wickets'].max().sort_values(ascending=False).head()

# %%
player
# Out:
# best_bowling
# Yuzvendra Chahal     5
# Wanindu Hasaranga    5
# Umran Malik          5
# Jasprit Bumrah       5
# Kuldeep Sen          4
# Name: highest_wickets, dtype: int32

# %%
aplayer = df.loc[df.groupby('best_bowling')['highest_wickets'].idxmax()][
    ['best_bowling', 'highest_wickets', 'best_bowling_figure']
].sort_values('highest_wickets', ascending=False)
